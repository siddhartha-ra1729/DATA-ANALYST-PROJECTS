# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('just data.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
sns.distplot(df['residual sugar'])
# Out:
# C:\Users\shaw3\AppData\Local\Temp\ipykernel_10188\107078400.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['residual sugar'])
# <Axes: xlabel='residual sugar', ylabel='Density'>

# %%
# Select only numerical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns
num_cols
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
#  # 1st method

# %% [markdown]
# # z-score method

# %%
# find the limits
upper_limit= df['residual sugar'].mean() + 3*df['residual sugar'].std()
lower_limit= df['residual sugar'].mean() - 3*df['residual sugar'].std()
print(upper_limit)
print(lower_limit)
# Out:
# 21.607588215254115
# -8.824758488835169

# %% [markdown]
# # find the outliers

# %%
df.loc[(df['residual sugar']> upper_limit) |  (df['residual sugar']< lower_limit) ]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 182             6.8             0.280         0.40           22.00      0.048
# 191             6.8             0.280         0.40           22.00      0.048
# 1608            6.9             0.270         0.49           23.50      0.057
# 1653            7.9             0.330         0.28           31.60      0.053
# 1663            7.9             0.330         0.28           31.60      0.053
# 2781            7.8             0.965         0.60           65.80      0.074
# 3619            6.8             0.450         0.28           26.05      0.031
# 3623            6.8             0.450         0.28           26.05      0.031
# 4480            5.9             0.220         0.45           22.60      0.120
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 182                  48.0                 167.0  1.00100  2.93       0.50
# ...

# %% [markdown]
# # trimming - detect the outlier data

# %%
new_df= df.loc[(df['residual sugar']< upper_limit) &  (df['residual sugar']> lower_limit) ]
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print('before remove outliers', len(df))
print('after removing outliers', len(new_df))
print('outliers', len(df)- len(new_df))
# Out:
# before remove outliers 4898
# after removing outliers 4889
# outliers 9

# %%
sns.boxplot(new_df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # 2nd method

# %% [markdown]
# # IQR METHOD

# %%
q1= df['residual sugar'].quantile(0.25) # 25%
q3= df['residual sugar'].quantile(0.75) #75%
iqr= q3- q1

# %%
q1, q3, iqr
# Out:
# (np.float64(1.7), np.float64(9.9), np.float64(8.200000000000001))

# %%
upper_limit= q3 + (1.5* iqr)
lower_limit= q1 - (1.5*iqr)

# %%
upper_limit
#lower_limit
# Out:
# np.float64(22.200000000000003)

# %%
lower_limit
# Out:
# np.float64(-10.600000000000001)

# %%
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
new1_df= df.loc[(df['residual sugar']< upper_limit) &  (df['residual sugar']> lower_limit) ]
new1_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print('before remove outliers', len(df))
print('after removing outliers', len(new1_df))
print('outliers', len(df)- len(new1_df))
# Out:
# before remove outliers 4898
# after removing outliers 4891
# outliers 7

# %%
sns.boxplot(new1_df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %% [markdown]
# # 3rd method

# %% [markdown]
# # parcentile method

# %%
upper_limit= df['residual sugar'].quantile(0.99) # 99% for check upper limit value
lower_limit= df['residual sugar'].quantile(0.01) # 1% for check lower limit value

# %%
upper_limit
# Out:
# np.float64(18.8)

# %%
lower_limit
# Out:
# np.float64(0.9)

# %%
df.loc[(df['residual sugar']> upper_limit) |  (df['residual sugar']< lower_limit) ]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 14              8.3             0.420         0.62           19.25      0.040
# 103             7.5             0.305         0.40           18.90      0.059
# 172             7.6             0.480         0.37            0.80      0.037
# ...             ...               ...          ...             ...        ...
# 4694            6.9             0.190         0.31           19.25      0.043
# 4778            5.8             0.315         0.19           19.40      0.031
# 4779            6.0             0.590         0.00            0.80      0.037
# 4877            5.9             0.540         0.00            0.80      0.032
# 4897            6.0             0.210         0.38            0.80      0.020
#
# ...

# %%
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %%
new2_df= df.loc[(df['residual sugar']<= upper_limit) &  (df['residual sugar']>= lower_limit) ]
new2_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# ...             ...               ...          ...             ...        ...
# 4892            6.5              0.23         0.38             1.3      0.032
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
#
# ...

# %%
print('before remove outliers', len(df))
print('after removing outliers', len(new2_df))
print('outliers', len(df)- len(new2_df))
# Out:
# before remove outliers 4898
# after removing outliers 4817
# outliers 81

# %%
sns.boxplot(new2_df['residual sugar'])
# Out:
# <Axes: ylabel='residual sugar'>

# %% [markdown]
# # special method

# %% [markdown]
# # capping method

# %%
upper_limit= df['residual sugar'].mean() + 3*df['residual sugar'].std()
lower_limit= df['residual sugar'].mean()-  3*df['residual sugar'].std()

# %%
df['residual sugar']= np.where(
    df['residual sugar']> upper_limit,
    upper_limit,
    np.where(
        df['residual sugar']< lower_limit,
        lower_limit,
        df['residual sugar']
    )
)

# %%
df['residual sugar'].describe()
# Out:
# count    4898.000000
# mean        6.375749
# std         4.979963
# min         0.600000
# 25%         1.700000
# 50%         5.200000
# 75%         9.900000
# max        21.607588
# Name: residual sugar, dtype: float64
