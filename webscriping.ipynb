# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests

# %%
web= requests.get("https://www.wscubetech.com/")
web
# Out:
# <Response [200]>

# %%
web.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="viewport" content="initial-scale=1.0, width=device-width"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="stylesheet" href="/_next/static/css/0bb41860bda823af.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/628779d13563f190.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/b7389e848453e16b.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/8cb7b7335a3a053c.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-6424df5a3dab904f.js"/><script src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js" async=""></script><script src="/_next/static/chunks/7023-7d602368a0a381e0.js" async=""></script><script src="/_next/static/chunks/main-app-55bbd77d
# ...

# %%
web.url
# Out:
# 'https://www.wscubetech.com/'

# %%
web.status_code
# Out:
# 200

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

# %%
web.status_code
# Out:
# 200

# %%
web.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"/><meta name="viewport" content="initial-scale=1.0, width=device-width"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="stylesheet" href="/_next/static/css/0bb41860bda823af.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/628779d13563f190.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/b7389e848453e16b.css" data-precedence="next"/><link rel="stylesheet" href="/_next/static/css/8cb7b7335a3a053c.css" data-precedence="next"/><link rel="preload" as="script" fetchPriority="low" href="/_next/static/chunks/webpack-6424df5a3dab904f.js"/><script src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js" async=""></script><script src="/_next/static/chunks/7023-7d602368a0a381e0.js" async=""></script><script src="/_next/static/chunks/main-app-55bbd77d
# ...

# %%
soup= BeautifulSoup(web.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/b7389e848453e16b.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-6424df5a3dab904f.js" rel="preload"/>
#   <script async="" src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js">
#   </script>
# ...

# %% [markdown]
# using this we can convert content(which is in html) is in a structure format

# %%
soup.title
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.p
# Out:
# <p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
soup.a
# Out:
# <a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/></span></a>

# %%
soup.h1
# Out:
# <h1 class="fs-40 fw-600 lh-48 text-color-2 mb-lg-32 mb-20" style="opacity:0;transform:translateY(-10px) translateZ(0)">Don’t Just Upskill, Get Career-ready, Get Hired</h1>

# %% [markdown]
# Find all tags and structure

# %% [markdown]
# TAG:

# %%
tag= soup.html()

# %%
type(tag)
# Out:
# bs4.element.ResultSet

# %%
tag= soup.p
tag
# Out:
# <p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
tag= soup.h2
tag
# Out:
# <h2 class="fs-32 fw-lg-600 fw-700 lh-40 text-color-1 mb-16">Mentorship Programs</h2>

# %%
tag= soup.a
tag
# Out:
# <a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/></span></a>

# %% [markdown]
# NavigableString:

# %%
tag= soup.p.string
tag
# Out:
# 'Elevate Your Learning Journey with Cutting-Edge Education Technology.'

# %%
tag= soup.h2.string
tag
# Out:
# 'Mentorship Programs'

# %%
tag= soup.h3.string
tag
# Out:
# 'Web Development'

# %% [markdown]
# Get string from tags using NavigableString

# %%
soup.name
# Out:
# '[document]'

# %%
soup.title
# Out:
# <title>WsCube Tech: Online Certification Courses &amp; Live Training</title>

# %%
soup.head
# Out:
# <head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/><meta content="initial-scale=1.0, width=device-width" name="viewport"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/b7389e848453e16b.css" rel="stylesheet"/><link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/><link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-6424df5a3dab904f.js" rel="preload"/><script async="" src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js"></script><script async="" src="/_next/static/chunks/7023-7d602368a0a381e0.js"></script><script async="" src="/_next/static/chunks/main-app-55bbd77d79f9187f.js"></script><s
# ...

# %%
soup.body
# Out:
# <body><noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-52JC74P" style="display:none;visibility:hidden" width="0"></iframe>
# ...

# %% [markdown]
# Find & Findall Function uses:

# %%
soup.find("p")
# Out:
# <p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>

# %%
soup.find_all("p")
# Out:
# [<p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>,
#  <p class="fs-18 fw-400 lh-28 mb-lg-0 mb-25 text-color-2" style="opacity:0;transform:translateY(10px) translateZ(0)">Top Mentorship Programs in Tech, Marketing, &amp; Data- Designed and Delivered by industry maestros.</p>,
#  <p class="fs-16 fw-400 lh-24 mb-40 text-color-7">Choose your program, get certified, and grab new career opportunities.</p>,
#  <p class="text-white fs-14 lh-21 fw-400 mb-24" style="opacity:0;transform:translateX(-30px) translateZ(0)">Discover career paths that truly resonate with your passion &amp; explore mentorship programs that align perfectly with you.</p>,
#  <p class="fs-14 lh-21 fw-400 text-color-7 mb-40">Join our rapidly growing learning community and acquire real-world skills.</p>,
#  <p class="m-0 fs-14">Empowering futures through skilled students trained by our EdTech expertise</p>,
# ...

# %%
soup.find("a")
# Out:
# <a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/></span></a>

# %%
soup.find_all("a")
# Out:
# [<a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/></span></a>,
#  <a class="nav-items-link cursor-pointer" href="/events"><div class="nav-items-link cursor-pointer"><span class="text-color-2 fs-16 fw-600 lh-24 d-block py-lg-16 px-lg-20 px-12 px-16 apply-as-mentor-btn">Masterclass</span></div></a>,
#  <a class="d-block" href="/"><img alt="logo" data-nimg="1" decoding="async" height="48" loading="lazy" src="/images/ws-cube-white-logo.svg" style="color:transparent" width="120"/></a>,
#  <a class="" href="/about"><span class="d-inline-block py-12 px-16 fs-14 fw-600 lh-21 text-color-2">About Us</span></a>,
#  <a href="/jaipur"><div class="fs-16 fw-400 lh-24 text-color-2">- <span class="label-gray fw-400 fs-14"> Jaipur</span></div></a>,
# ...

# %% [markdown]
# Comments:

# %% [markdown]
# Comments use to get the comment part  fron the code

# %%
com=  soup.p.string
com
# Out:
# 'Elevate Your Learning Journey with Cutting-Edge Education Technology.'

# %%
soup.p.prettify()
# Out:
# '<p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">\n Elevate Your Learning Journey with Cutting-Edge Education Technology.\n</p>\n'

# %% [markdown]
# using prettify we can create a structure and systematic format of code

# %% [markdown]
# Class data find:

# %%
class_data= soup.find("div", class_ = "fs-12 fw-400 lh-18 text-color-19 courses-link-text")
class_data
# Out:
# <div class="fs-12 fw-400 lh-18 text-color-19 courses-link-text"><span class="courses-name">Digital Marketing Course</span><span class="px-10">|</span></div>

# %%
class_data.find_all("a")
# Out:
# []

# %%
id_data= soup.find("div", id_= )

# %% [markdown]
# Extracting text from page:

# %%
lines= soup.find_all("p")
lines
# Out:
# [<p class="text-color-19 fs-14 fw-600 lh-21 mb-0 text-color-19">Elevate Your Learning Journey with Cutting-Edge Education Technology.</p>,
#  <p class="fs-18 fw-400 lh-28 mb-lg-0 mb-25 text-color-2" style="opacity:0;transform:translateY(10px) translateZ(0)">Top Mentorship Programs in Tech, Marketing, &amp; Data- Designed and Delivered by industry maestros.</p>,
#  <p class="fs-16 fw-400 lh-24 mb-40 text-color-7">Choose your program, get certified, and grab new career opportunities.</p>,
#  <p class="text-white fs-14 lh-21 fw-400 mb-24" style="opacity:0;transform:translateX(-30px) translateZ(0)">Discover career paths that truly resonate with your passion &amp; explore mentorship programs that align perfectly with you.</p>,
#  <p class="fs-14 lh-21 fw-400 text-color-7 mb-40">Join our rapidly growing learning community and acquire real-world skills.</p>,
#  <p class="m-0 fs-14">Empowering futures through skilled students trained by our EdTech expertise</p>,
# ...

# %%
for l in lines:
    print(l.text)
# Out:
# Elevate Your Learning Journey with Cutting-Edge Education Technology.
# Top Mentorship Programs in Tech, Marketing, & Data- Designed and Delivered by industry maestros.
# Choose your program, get certified, and grab new career opportunities.
# Discover career paths that truly resonate with your passion & explore mentorship programs that align perfectly with you.
# Join our rapidly growing learning community and acquire real-world skills.
# Empowering futures through skilled students trained by our EdTech expertise
# Grab actionable career insights with recommended mentorship programs designed to turn your passion into a profession.
# Replicating online impact through offline centers city-by-city.
# Rajasthan
# Rajasthan
# to your city
# 1st Floor, Plot no. 21, Manav Ashram Colony, Vasundhara Colony, Gopal Pura Mode, Jaipur - Rajasthan - India (302018)
# ...

# %%
s1= soup.find_all("p", class_= "courses-name")
s1
# Out:
# []

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link data-precedence="next" href="/_next/static/css/0bb41860bda823af.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/628779d13563f190.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/b7389e848453e16b.css" rel="stylesheet"/>
#   <link data-precedence="next" href="/_next/static/css/8cb7b7335a3a053c.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-6424df5a3dab904f.js" rel="preload"/>
#   <script async="" src="/_next/static/chunks/fd9d1056-1bba0d9253bf5d9e.js">
#   </script>
# ...

# %%
for i in soup.find_all("a"):
    print(i)
# Out:
# <a href="/" title="WsCube Tech"><span class="d-block web-logo"><img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/></span></a>
# <a class="nav-items-link cursor-pointer" href="/events"><div class="nav-items-link cursor-pointer"><span class="text-color-2 fs-16 fw-600 lh-24 d-block py-lg-16 px-lg-20 px-12 px-16 apply-as-mentor-btn">Masterclass</span></div></a>
# <a class="d-block" href="/"><img alt="logo" data-nimg="1" decoding="async" height="48" loading="lazy" src="/images/ws-cube-white-logo.svg" style="color:transparent" width="120"/></a>
# <a class="" href="/about"><span class="d-inline-block py-12 px-16 fs-14 fw-600 lh-21 text-color-2">About Us</span></a>
# <a href="/jaipur"><div class="fs-16 fw-400 lh-24 text-color-2">- <span class="label-gray fw-400 fs-14"> Jaipur</span></div></a>
# ...

# %%
for i in soup.find_all("a"):
    print(i.get("href"))
# Out:
# /
# /events
# /
# /about
# /jaipur
# /jodhpur
# /events
# /contact
# /
# https://twitter.com/wscubetechindia
# https://www.instagram.com/wscubetechindia/
# https://in.linkedin.com/company/wscubetechindia
# https://www.youtube.com/c/wscubetechjodhpur
# https://www.facebook.com/wscubetech.india
# /contact
# /about
# https://www.wscubetech.com/blog/
# https://courses.wscubetech.com/
# /events
# /data-analytics-course
# /marketing
# /full-stack-developer-course
# /cyber-security
# /mobile-app-development-course
# /privacy-policy
# /terms-and-conditions
# /refund-and-cancellation
# /faq
# /digital-marketing-course
# /data-analytics-course
# /full-stack-developer-course
# /performance-marketing-course
# /seo-course
# /ethical-hacking-course
# /mobile-app-development-course
# /resources/semrush/free-course
# /resources/google-tag-manager/free-course
# /resources/blogging/free-course
# /resources/photoshop/free-course
# /resources/video-editing/free-course
# /resources/angular/free-course
# ...

# %% [markdown]
# FIND IMAGE :

# %%
img= soup.find_all("img")
img
# Out:
# [<img alt="header-logo" data-nimg="1" decoding="async" height="60" loading="lazy" src=" /images/ws-cube-white-logo.svg" style="color:transparent" width="149"/>,
#  <img alt="logo" data-nimg="1" decoding="async" height="48" loading="lazy" src="/images/ws-cube-white-logo.svg" style="color:transparent" width="120"/>,
#  <img alt="menu" data-nimg="1" decoding="async" height="16" loading="lazy" src="https://deen3evddmddt.cloudfront.net/images/mobile-menu-icon.svg" style="color:transparent" width="24"/>,
#  <img alt="footer-logo" data-nimg="1" decoding="async" height="72" loading="lazy" src="https://deen3evddmddt.cloudfront.net/images/ws-cube-white-logo.svg" style="color:transparent" width="180"/>,
#  <img alt="instruction-icon" class="img-fluid" data-nimg="1" decoding="async" height="18" loading="lazy" src="https://deen3evddmddt.cloudfront.net/images/icons/instructors-icon.svg" style="color:transparent" width="20"/>,
# ...

# %%
word_titles= soup.find_all('th')
word_titles
# Out:
# []

# %%
soup.find_all("th")
# Out:
# []

# %%
table= soup.find("table")
table
